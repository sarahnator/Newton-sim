# %%
import os
os.chdir("/geoelements/sarahnator/")
# !git clone https://github.com/Lightricks/LTX-2.git
# %cd /content/LTX-2


# !pip install -q uv
# !uv sync --frozen
# Out:
# Cloning into 'LTX-2'...
# remote: Enumerating objects: 842, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 842 (delta 3), reused 1 (delta 1), pack-reused 799 (from 2)
# Receiving objects: 100% (842/842), 2.11 MiB | 9.47 MiB/s, done.
# Resolving deltas: 100% (277/277), done.
# /content/LTX-2
# error: No `pyproject.toml` found in current directory or any parent directory

# %%
# !uv pip install huggingface_hub
# !uv sync --frozen

# %%
# !hf auth login

# !sudo mkdir -p /content/LTX-2/models
# !sudo mkdir -p /content/LTX-2/models/gemma

# !hf download Lightricks/LTX-2 ltx-2-19b-dev.safetensors --local-dir /content/LTX-2/models
# !hf download Lightricks/LTX-2 ltx-2-19b-distilled-lora-384.safetensors --local-dir /content/LTX-2/models
# !hf download Lightricks/LTX-2 ltx-2-spatial-upscaler-x2-1.0.safetensors --local-dir /content/LTX-2/models


# !mkdir -p /content/LTX-2/models/gemma

# !hf download google/gemma-3-12b-it --local-dir /content/LTX-2/models/gemma
# !hf download Lightricks/LTX-2 tokenizer/preprocessor_config.json --local-dir /content/LTX-2/models/gemma

# %%
import os
os.chdir("/geoelements/sarahnator/Newton-sim")
# !hf download Lightricks/LTX-2 ltx-2-19b-dev.safetensors --local-dir /content/LTX-2/models
# !hf download Lightricks/LTX-2 ltx-2-19b-distilled-lora-384.safetensors --local-dir /content/LTX-2/models
# !hf download Lightricks/LTX-2 ltx-2-spatial-upscaler-x2-1.0.safetensors --local-dir /content/LTX-2/models

# !hf download google/gemma-3-12b-it --local-dir /content/LTX-2/models/gemma
# !hf download Lightricks/LTX-2 tokenizer/preprocessor_config.json --local-dir /content/LTX-2/models/gemma
# Out:
# Traceback (most recent call last):
#   File "/home/sarahnator/miniconda3/lib/python3.13/pathlib/_local.py", line 722, in mkdir
#     os.mkdir(self, mode)
#     ~~~~~~~~^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/content/LTX-2/models/.cache/huggingface'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/geoelements/sarahnator/Newton-sim/.venv/bin/hf", line 10, in <module>
#     sys.exit(main())
#              ~~~~^^
#   File "/geoelements/sarahnator/Newton-sim/.venv/lib/python3.13/site-packages/huggingface_hub/cli/hf.py", line 114, in main
#     app()
#     ~~~^^
#   File "/geoelements/sarahnator/Newton-sim/.venv/lib/python3.13/site-packages/typer/main.py", line 1152, in __call__
#     raise e
#   File "/geoelements/sarahnator/Newton-sim/.venv/lib/python3.13/site-packages/typer/main.py", line 1135, in __call__
#     return get_command(self)(*args, **kwargs)
# ...
